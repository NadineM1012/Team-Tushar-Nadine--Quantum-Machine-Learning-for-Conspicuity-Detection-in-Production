# %%
import matplotlib.pyplot as plt

# Data for IQP Embedding Training
epochs_iqp = list(range(1, 7))
train_loss_iqp = [0.5528, 0.4098, 0.3157, 0.2687, 0.2331, 0.2059]
val_loss_iqp = [0.4446, 0.3808, 0.3360, 0.2996, 0.2790, 0.2629]
train_acc_iqp = [0.7869, 0.8488, 0.8714, 0.8881, 0.9119, 0.9202]
val_acc_iqp = [0.8333, 0.8708, 0.8500, 0.8875, 0.8958, 0.9208]

# Data for Angle Embedding Training
epochs_angle = list(range(1, 15))
train_loss_angle = [0.5003, 0.3916, 0.3160, 0.2704, 0.2399, 0.2209, 0.2101, 0.1987, 0.1957, 0.1806, 0.1690, 0.1566, 0.1564, 0.1451]
val_loss_angle = [0.4039, 0.3397, 0.2941, 0.2573, 0.2302, 0.2112, 0.1980, 0.1959, 0.1796, 0.1707, 0.1640, 0.1587, 0.1548, 0.1485]
train_acc_angle = [0.8286, 0.8536, 0.8488, 0.8976, 0.8976, 0.9202, 0.9119, 0.9274, 0.9143, 0.9333, 0.9381, 0.9488, 0.9500, 0.9524]
val_acc_angle = [0.8333, 0.8375, 0.8833, 0.8917, 0.9083, 0.9125, 0.9458, 0.9125, 0.9625, 0.9375, 0.9542, 0.9625, 0.9583, 0.9625]

# Plotting IQP Embedding
plt.figure(figsize=(14, 10))

plt.subplot(2, 2, 1)
plt.plot(epochs_iqp, train_loss_iqp, label='Train Loss', marker='o')
plt.plot(epochs_iqp, val_loss_iqp, label='Validation Loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('IQP Embedding Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs_iqp, train_acc_iqp, label='Train Accuracy', marker='o')
plt.plot(epochs_iqp, val_acc_iqp, label='Validation Accuracy', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('IQP Embedding Accuracy')
plt.legend()

# Plotting Angle Embedding
plt.subplot(2, 2, 3)
plt.plot(epochs_angle, train_loss_angle, label='Train Loss', marker='o')
plt.plot(epochs_angle, val_loss_angle, label='Validation Loss', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Angle Embedding Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs_angle, train_acc_angle, label='Train Accuracy', marker='o')
plt.plot(epochs_angle, val_acc_angle, label='Validation Accuracy', marker='o')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Angle Embedding Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
