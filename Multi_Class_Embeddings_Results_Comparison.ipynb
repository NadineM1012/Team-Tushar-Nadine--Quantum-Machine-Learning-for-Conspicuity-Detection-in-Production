# %%
import matplotlib.pyplot as plt

# Data for IQP Embedding
epochs_iqp = list(range(1, 21))
train_loss_iqp = [1.2098, 0.8455, 0.5790, 0.3775, 0.2568, 0.1907, 0.1569, 0.1299, 0.1153, 0.0950, 0.0825, 0.0714, 0.0624, 0.0509, 0.0454, 0.0398, 0.0365, 0.0294, 0.0259, 0.0232]
validation_loss_iqp = [1.1213, 0.8084, 0.5734, 0.4175, 0.3033, 0.2709, 0.2244, 0.2000, 0.1776, 0.1657, 0.1539, 0.1485, 0.1315, 0.1346, 0.1243, 0.1228, 0.1171, 0.1225, 0.1153, 0.1163]
train_acc_iqp = [0.5893, 0.7821, 0.8768, 0.9143, 0.9357, 0.9446, 0.9554, 0.9625, 0.9643, 0.9696, 0.9786, 0.9875, 0.9893, 0.9929, 0.9929, 0.9982, 0.9946, 1.0000, 1.0000, 1.0000]
validation_acc_iqp = [0.6875, 0.8688, 0.9062, 0.9000, 0.9125, 0.9375, 0.9375, 0.9437, 0.9437, 0.9625, 0.9500, 0.9625, 0.9625, 0.9625, 0.9563, 0.9688, 0.9500, 0.9625, 0.9437, 0.9625]

# Data for Angle Embedding
epochs_angle = list(range(1, 21))
train_loss_angle = [1.1728, 0.7603, 0.4717, 0.3141, 0.2474, 0.1959, 0.1633, 0.1496, 0.1300, 0.1156, 0.1054, 0.0961, 0.0939, 0.0800, 0.0719, 0.0633, 0.0620, 0.0562, 0.0501, 0.0457]
validation_loss_angle = [1.1503, 0.8316, 0.6385, 0.4670, 0.3891, 0.3172, 0.2856, 0.2317, 0.2215, 0.1902, 0.1868, 0.1621, 0.1498, 0.1435, 0.1395, 0.1273, 0.1375, 0.1163, 0.1115, 0.1197]
train_acc_angle = [0.5554, 0.8054, 0.8893, 0.9089, 0.9214, 0.9321, 0.9429, 0.9518, 0.9500, 0.9589, 0.9571, 0.9625, 0.9679, 0.9714, 0.9750, 0.9839, 0.9821, 0.9857, 0.9857, 0.9893]
validation_acc_angle = [0.6813, 0.8313, 0.8500, 0.8750, 0.8875, 0.9062, 0.9125, 0.9437, 0.9500, 0.9500, 0.9500, 0.9625, 0.9750, 0.9625, 0.9625, 0.9812, 0.9625, 0.9812, 0.9750, 0.9688]

# Plotting
plt.figure(figsize=(12, 8))

# Plot for IQP Embedding
plt.subplot(2, 2, 1)
plt.plot(epochs_iqp, train_loss_iqp, label='Train Loss', marker='o')
plt.plot(epochs_iqp, validation_loss_iqp, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('IQP Embedding Loss')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(epochs_iqp, train_acc_iqp, label='Train Accuracy', marker='o')
plt.plot(epochs_iqp, validation_acc_iqp, label='Validation Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('IQP Embedding Accuracy')
plt.legend()

# Plot for Angle Embedding
plt.subplot(2, 2, 3)
plt.plot(epochs_angle, train_loss_angle, label='Train Loss', marker='o')
plt.plot(epochs_angle, validation_loss_angle, label='Validation Loss', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Angle Embedding Loss')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(epochs_angle, train_acc_angle, label='Train Accuracy', marker='o')
plt.plot(epochs_angle, validation_acc_angle, label='Validation Accuracy', marker='o')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Angle Embedding Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
