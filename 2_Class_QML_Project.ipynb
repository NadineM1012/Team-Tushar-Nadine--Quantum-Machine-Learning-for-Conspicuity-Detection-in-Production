png
#   inflating: al5083/train/170906-153326-Al 2mm-part1/frame_00645.png
#   inflating: al5083/train/170906-153326-Al 2mm-part1/frame_00646.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00680.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00681.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00682.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00683.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00684.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00685.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00686.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00687.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00688.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00689.png
#   inflating: al5083/train/170906-153326-Al 2mm-part2/frame_00690.png
# ...
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01094.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01095.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01096.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01097.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01098.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01099.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01100.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01101.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01102.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01103.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01104.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01105.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01106.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01107.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01108.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01109.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01110.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01111.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01112.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01113.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01114.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01115.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01116.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01117.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01118.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01119.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01120.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01121.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01122.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01123.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01124.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01125.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01126.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01127.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01128.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01129.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01130.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01131.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01132.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01133.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01134.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01135.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01136.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01137.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01138.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01139.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01140.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01141.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01142.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01143.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01144.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01145.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01146.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01147.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01148.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01149.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01150.png
#   inflating: al5083/train/170913-155806-Al 2mm-part1/frame_01151.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01435.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01436.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01437.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01438.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01439.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01440.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01441.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01442.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01443.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01444.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01445.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01446.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01447.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01448.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01449.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01450.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01451.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01452.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01453.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01454.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01455.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01456.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01457.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01458.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01459.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01460.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01461.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01462.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01463.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01464.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01465.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01466.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01467.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01468.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01469.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01470.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01471.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01472.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01473.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01474.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01475.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01476.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01477.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01478.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01479.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01480.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01481.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01482.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01483.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01484.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01485.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01486.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01487.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01488.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01489.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01490.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01491.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01492.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01493.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01494.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01495.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01496.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01497.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01498.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01499.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01500.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01501.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01502.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01503.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01504.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01505.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01506.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01507.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01508.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01509.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01510.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01511.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01512.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01513.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01514.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01515.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01516.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01517.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01518.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01519.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01520.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01521.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01522.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01523.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01524.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01525.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01526.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01527.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01528.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01529.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01530.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01531.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01532.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01533.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01534.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01535.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01536.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01537.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01538.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01539.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01540.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01541.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01542.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01543.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01544.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01545.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01546.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01547.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01548.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01549.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01550.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01551.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01552.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01553.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01554.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01555.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01556.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01557.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01558.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01559.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01560.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01561.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01562.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01563.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01564.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01565.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01566.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01567.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01568.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01569.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01570.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01571.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01572.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01573.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01574.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01575.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01576.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01577.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01578.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01579.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01580.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01581.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01582.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01583.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01584.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01585.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01586.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01587.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01588.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01589.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01590.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01591.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01592.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01593.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01594.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01595.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01596.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01597.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01598.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01599.png
#   inflating: al5083/train/170913-155806-Al 2mm-part2/frame_01600.png
#   inflating: al5083/train/train.json

# %%
# Open the training file
f = open('/content/al5083/train/train.json') # Colab version
# f = open('al5083/train/train.json') # Local version
data = json.load(f)

# Create a dictionary to store the data
data_dict = {0:[], 1:[], 2:[],
             3:[], 4: [], 5:[]}
for id, (key, value) in enumerate(data.items()):
      data_dict[value].append(key)

# Close the file
f.close()

# %%
def sample_portion_each(data_dict, num_samples = 500):
    # Sample a portion of each class
    sampled_dict = {}
    for key, value in data_dict.items():
        if len(value) >= num_samples:
            sampled_dict[key] = sample(value, num_samples)
        else:
            sampled_dict[key] = value
    return sampled_dict

# Sampled dictionary
sampled_dict = sample_portion_each(data_dict)

# Create a dataframe for our dataset
df = pd.DataFrame([(k, v) for k, values in sampled_dict.items() for v in values], columns=['label', 'img'])

# %%
# Dataset class
class Aluminium5083Dataset(Dataset):
    def __init__(self, df, transforms=None):
        self.df = df
        self.transforms = transforms

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        # Get the label corresponding to the Id
        label = self.df.iloc[idx]['label']
        # Get the image path
        img_path = os.path.join('/content/al5083/train/', self.df.iloc[idx]['img'])
        # Open the image
        img = Image.open(img_path)
        # Binary labelling
        if label != 0:
            label = 1
        # Convert the image to tensor
        if self.transforms:
            img = self.transforms(img)
        # Return the image and label
        return img, label

# %%
# Transform data to tensor, resize and renormalize it
transforms = transforms.Compose([transforms.ToTensor(),
                                transforms.Resize((28, 28),antialias=False),
                                transforms.Normalize([0.2428], [0.1344]),
                                ])

# %%
# Create the transformed dataset
dataset = Aluminium5083Dataset(df=df, transforms=transforms)

# %%
# Create a 70-20-10 split for train-validation-test
train_size = int(0.7 * len(dataset))
val_size = int(0.2 * len(dataset))
test_size = len(dataset) - train_size - val_size

batch_size = 128
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size]) # Split the dataset

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)  # Create a DataLoader for the train set
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)  # Create a DataLoader for the validation set
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)  # Create a DataLoader for the test set

dataloaders = {'train': train_loader, 'validation': val_loader, 'test':test_loader} # Create a dictionary for the dataloaders

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dev = qml.device("lightning.qubit", wires=4)
# Set the number of layers and the width of the circuit
n_layers = 3
n_wires = 4

class Quanv(nn.Module):
    def __init__(self,n_layers):
        super(Quanv, self).__init__()
        # Number of layers
        self.n_layers = n_layers

        # Create a quantum circuit
        @qml.qnode(dev,interface="torch")
        def circuit(inputs,weights):
            # Angle Embedding and entanglement layers
            qml.AngleEmbedding(inputs, wires=range(n_wires))
            qml.BasicEntanglerLayers(weights, wires=range(n_wires))

            # Measurement
            return [qml.expval(qml.PauliZ(i)) for i in range(n_wires)]

        # Add a torch layer using weight shapes
        weight_shapes = {"weights": [self.n_layers, n_wires]}
        self.circuit = qml.qnn.TorchLayer(circuit, weight_shapes=weight_shapes)


    def forward(self, x):
        # Get the batch size, height, and width
        bs, ch, h, w = x.size()
        # Create a tensor to store the output
        output = torch.zeros((bs, 4, 14, 14)).to(x.device)

        # Loop over the coordinates of the top-left pixel of 2X2 squares
        for b in range(bs):
          for j in range(0, h, 2):
              for k in range(0, w, 2):
                  q_results = self.circuit(
                      torch.tensor([
                          x[b,0,j, k].item(),
                          x[b,0,j, k + 1].item(),
                          x[b,0,j + 1, k].item(),
                          x[b,0,j + 1, k + 1].item()
                      ]).to(x.device)
                  )

                  # Assign expectation values to different channels of the output pixel (j/2, k/2)
                  for c in range(4):
                     output[b,c,j // 2, k // 2] = q_results[c]
        return output

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs, batch_size):
    since = time.time()
    # Best model
    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    best_loss = 10000.0
    best_acc_train = 0.0
    best_loss_train = 10000.0
    print("Training started:")

    for epoch in range(num_epochs):
        # Cross validation
        for phase in ["train", "validation"]:
            # Set model mode
            if phase == "train":
                model.train()
            else:
                model.eval()
            running_loss = 0.0
            running_corrects = 0
            n_batches = len(dataloaders[phase].dataset) // batch_size
            # Batch iteration counter
            it = 0
            for i, (inputs, labels) in enumerate(dataloaders[phase]):
                since_batch = time.time()
                inputs = inputs.to(device)
                labels = labels.to(device)
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase == "train"):
                    # Get outputs
                    outputs = model(inputs)
                    # Get predictions
                    _, preds = torch.max(outputs, 1)
                    # Compute loss using criterion
                    loss = criterion(outputs, labels)
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                # Calculating the loss
                running_loss += loss.item() * batch_size
                # Calculating the accuracy
                batch_corrects = torch.sum(preds == labels.data).item()
                running_corrects += batch_corrects
                # Print iteration counter
                print("Phase: {} Epoch: {}/{} Iter: {}/{} Batch time: {:.4f}".format(
                        phase,
                        epoch + 1,
                        num_epochs,
                        it + 1,
                        n_batches + 1,
                        time.time() - since_batch,
                    ),
                    end="\r",
                    flush=True,
                )
                it += 1

            # Print epoch results
            epoch_loss = running_loss / len(dataloaders[phase].dataset)
            epoch_acc = running_corrects / len(dataloaders[phase].dataset)
            print(
                "Phase: {} Epoch: {}/{} Loss: {:.4f} Acc: {:.4f}        ".format(
                    phase,
                    epoch + 1,
                    num_epochs,
                    epoch_loss,
                    epoch_acc,
                )
            )

            # Check if this is the best model wrt previous epochs
            if phase == "validation" and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())
            if phase == "validation" and epoch_loss < best_loss:
                best_loss = epoch_loss
            if phase == "train" and epoch_acc > best_acc_train:
                best_acc_train = epoch_acc
            if phase == "train" and epoch_loss < best_loss_train:
                best_loss_train = epoch_loss

            # Update learning rate
            if phase == "validation":
                scheduler.step(epoch_loss)

    # Print final results
    model.load_state_dict(best_model_wts)
    time_elapsed = time.time() - since
    print("Training completed in {:.0f}m {:.0f}s".format(
        time_elapsed // 60, time_elapsed % 60
        ))
    print("Best test loss: {:.4f} | Best test accuracy: {:.4f}".format(best_loss, best_acc))
    return model

# %%
# Sequential model
model = torch.nn.Sequential(
        Quanv(n_layers=3),
        torch.nn.Flatten(),
        torch.nn.Linear(in_features=14*14*4,out_features=2)
    ).to(device)

# Optimizer, Scheduler and loss criterion
optimizer = torch.optim.Adam(params=model.parameters(), lr=5e-3, weight_decay=1e-5)
scheduler = ReduceLROnPlateau(optimizer, mode='min',factor=0.1, patience=5,min_lr=0.00002)
criterion = torch.nn.CrossEntropyLoss()
# model= train_model(model, criterion, optimizer, scheduler, num_epochs=20, batch_size = batch_size)
# Save the model
# torch.save(model.state_dict(), 'model_500_20.pth')

# %%
# Load the saved model
model.load_state_dict(torch.load('model_500_20.pth'))
# Out:
# <All keys matched successfully>

# %%
def scores(y_true, y_pred):
    f1 = f1_score(y_true, y_pred)
    roc = roc_auc_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    c_mat = confusion_matrix(y_true, y_pred)
    print("f1 score:{:.2f}, roc:{:.2f}, precision:{:.2f}, recall:{:.2f}, confusion matrix:{}".format(
    f1, roc, precision, recall, c_mat))
    return [f1,roc,precision, recall, c_mat]

def predictions(loader):
    y_pred = []
    y_true = []
    model.eval()
    with torch.no_grad():
        for images, labels in loader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs.data, 1)
            y_pred.extend(predicted.tolist())
            y_true.extend(labels.tolist())
    model.train()
    return y_true,y_pred

# %%
y_true, y_pred = predictions(test_loader)
f1,roc,precision, recall, c_mat = scores(y_true, y_pred)
# Out:
# f1 score:0.98, roc:0.96, precision:0.99, recall:0.97, confusion matrix:[[ 50   3]
#  [  7 240]]

# %%
accuracy = (np.array(y_pred) == np.array(y_true)).mean()
print("Accuracy:", 100*accuracy)
# Out:
# Accuracy: 96.66666666666667
